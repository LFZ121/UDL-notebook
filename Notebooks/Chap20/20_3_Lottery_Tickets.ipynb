# %% [markdown]
# <a href="https://colab.research.google.com/github/LFZ121/UDL-notebook/blob/main/Notebooks/Chap20/20_3_Lottery_Tickets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 20.3: Lottery tickets**
#
# This notebook investigates the phenomenon of lottery tickets as discussed in section 20.2.7.  This notebook is highly derivative of the MNIST-1D code hosted by Sam Greydanus at https://github.com/greydanus/mnist1d.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# !git clone https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-p61nt6w5
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-p61nt6w5
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (26.1)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2026.4.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14664 sha256=c7d7414f394a06b1af9480c1751d1548b71fbd7c8b83f508b1c10744c102f420
#   Stored in directory: /tmp/pip-ephem-wheel-cache-9gc7wkil/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16
# Cloning into 'mnist1d'...
# remote: Enumerating objects: 541, done.
# remote: Counting objects: 100% (129/129), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 541 (delta 120), reused 119 (delta 119), pack-reused 412 (from 1)
# Receiving objects: 100% (541/541), 14.54 MiB | 24.41 MiB/s, done.
# Resolving deltas: 100% (260/260), done.

# %% [markdown]
# # Lottery tickets
#
# Lottery tickets were first identified by [Frankle and Carbin (2018)](https://arxiv.org/abs/1803.03635).  They noted that after training a network, they could set the smaller weights to zero and clamp them there and retrain to get a network that was sparser (had fewer parameters) but could actually perform better.  So within the neural network there lie smaller sub-networks which are superior.  If we knew what these were, we could train them from scratch, but there is currently no way of finding out.

# %%
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import mnist1d
import copy

# %% [markdown]
# ## Get the MNIST1D dataset

# %%
from mnist1d.data import get_dataset, get_dataset_args
from mnist1d.utils import set_seed, to_pickle, from_pickle

import sys ; sys.path.append('./mnist1d/notebooks')
from train import get_model_args, train_model

args = mnist1d.get_dataset_args()
data = mnist1d.get_dataset(args=args)  # by default, this will download a pre-made dataset from the GitHub repo

print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each input: {}".format(data['x'].shape[-1]))
print("Number of classes: {}".format(len(data['templates']['y'])))
# Out:
# Downloading MNIST1D dataset from https://github.com/greydanus/mnist1d/raw/master/mnist1d_data.pkl
# Saving to ./mnist1d_data.pkl
# Successfully loaded data from ./mnist1d_data.pkl
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each input: 40
# Number of classes: 10

# %% [markdown]
# ## Make an MLP that can be masked
# These parameter-wise binary masks are how we will represent sparsity in this project. There's not a great PyTorch API for this yet, so here's a temporary solution.

# %%
# Class to represent linear layer where some of the weights are forced to zero.
class SparseLinear(torch.nn.Module):
  def __init__(self, x_size, y_size):
    super(SparseLinear, self).__init__()
    self.linear = torch.nn.Linear(x_size, y_size)
    param_vec = torch.cat([p.flatten() for p in self.parameters()])
    self.mask = torch.ones_like(param_vec)

  def forward(self, x, apply_mask=True):
    if apply_mask:
      self.apply_mask()
    return self.linear(x)

  def update_mask(self, new_mask):
    self.mask = new_mask
    self.apply_mask()

  def apply_mask(self):
    self.vec2param(self.param2vec())

  def param2vec(self):
    vec = torch.cat([p.flatten() for p in self.parameters()])
    return self.mask * vec

  def vec2param(self, vec):
    pointer = 0
    for param in self.parameters():
      param_len = np.cumprod(param.shape)[-1]
      new_param = vec[pointer:pointer+param_len].reshape(param.shape)
      param.data = new_param.data
      pointer += param_len

# A two layer residual network where the linear layers are sparse
class SparseMLP(torch.nn.Module):
  def __init__(self, input_size, output_size, hidden_size=100):
    super(SparseMLP, self).__init__()
    self.linear1 = SparseLinear(input_size, hidden_size)
    self.linear2 = SparseLinear(hidden_size, hidden_size)
    self.linear3 = SparseLinear(hidden_size, output_size)
    self.layers = [self.linear1, self.linear2, self.linear3]

  def forward(self, x):
    h = torch.relu(self.linear1(x))
    h = h + torch.relu(self.linear2(h))
    h = self.linear3(h)
    return h

  def get_layer_masks(self):
    return [l.mask for l in self.layers]

  def set_layer_masks(self, new_masks):
    for i, l in enumerate(self.layers):
      l.update_mask(new_masks[i])

  def get_layer_vecs(self):
    return [l.param2vec() for l in self.layers]

  def set_layer_vecs(self, vecs):
    for i, l in enumerate(self.layers):
      l.vec2param(vecs[i])

# %% [markdown]
# Now we need a routine that takes the weights from the model and returns a mask that identifies the positions with the lowest magnitude.  These will be the weights that we mask.

# %%
def get_mask(absolute_weights, percent_sparse):
  # Number of weights to prune
  n_weights = absolute_weights.numel()
  n_prune = int(percent_sparse * n_weights)

  # Start with all weights kept
  mask = torch.ones_like(absolute_weights)

  # If pruning nothing, return all ones
  if n_prune == 0:
    return mask

  # Find indices of the smallest-magnitude weights
  _, prune_indices = torch.topk(
      absolute_weights,
      k=n_prune,
      largest=False
  )

  # Set those positions to zero
  mask[prune_indices] = 0

  return mask

# %% [markdown]
# ## The prune-and-retrain cycle
# This is the core method for finding a lottery ticket. We train a model for a fixed number of epochs, prune it, and then re-train and re-prune. We repeat this cycle until we achieve the desired level of sparsity.

# %%
def find_lottery_ticket(model, dataset, args, sparsity_schedule, criteria_fn=None, **kwargs):

  criteria_fn = lambda init_params, final_params: final_params.abs()
  init_params = model.get_layer_vecs()
  stats = {'train_losses':[], 'test_losses':[], 'train_accs':[], 'test_accs':[]}
  models = []
  for i, percent_sparse in enumerate(sparsity_schedule):

    # layer-wise pruning, where pruning heuristic is determined by criteria_fn
    final_params = model.get_layer_vecs()
    scores = [criteria_fn(ip, fp) for ip, fp in zip(init_params, final_params)]
    masks = [get_mask(s, percent_sparse) for s in scores]

    # update model with mask and init parameters
    model.set_layer_vecs(init_params)
    model.set_layer_masks(masks)

    # training process
    results = train_model(dataset, model, args)
    model = results['checkpoints'][-1]

    # store stats
    stats['train_losses'].append(results['train_losses'])
    stats['test_losses'].append(results['test_losses'])
    stats['train_accs'].append(results['train_acc'])
    stats['test_accs'].append(results['test_acc'])

    # print progress
    if (i+1) % 1 == 0:
      print('\tretrain #{}, sparsity {:.2f}, final_train_loss {:.3e}, max_acc {:.1f}, last_acc {:.1f}, mean_acc {:.1f}'
            .format(i+1, percent_sparse, results['train_losses'][-1], np.max(results['test_acc']),
            results['test_acc'][-1], np.mean(results['test_acc']) ))
      models.append(copy.deepcopy(model))

  stats = {k: np.stack(v) for k, v in stats.items()}
  return models, stats

# %% [markdown]
# ## Choose hyperparameters

# %%
# train settings
from train import get_model_args, train_model
model_args = get_model_args()
model_args.total_steps = 1501
model_args.hidden_size = 500
model_args.print_every = 5000 # print never
model_args.eval_every = 100
model_args.learning_rate = 2e-2
model_args.device = str('cpu')

# %% [markdown]
# Find the lottery ticket by repeatedly training and then pruning weights based on their magnitudes. We'll remove 1% of the weights each time. This is going to take half an hour or so.  Go and have lunch or whatever.

# %%
# sparsity settings - we will train 100 models with progressively increasing sparsity
num_retrains = 100
sparsity_schedule = np.linspace(0,1.,num_retrains)

print("Magnitude pruning")
mnist1d.set_seed(model_args.seed)
model = SparseMLP(model_args.input_size, model_args.output_size, hidden_size=model_args.hidden_size)

criteria_fn = lambda init_params, final_params: final_params.abs()
lott_models, lott_stats = find_lottery_ticket(model, data, model_args, sparsity_schedule, criteria_fn=criteria_fn, prune_print_every=1)
# Out:
# Magnitude pruning
# 	retrain #1, sparsity 0.00, final_train_loss 6.628e-02, max_acc 65.3, last_acc 65.3, mean_acc 57.0
# 	retrain #2, sparsity 0.01, final_train_loss 4.879e-01, max_acc 64.8, last_acc 62.0, mean_acc 56.9
# 	retrain #3, sparsity 0.02, final_train_loss 4.513e-01, max_acc 64.7, last_acc 62.4, mean_acc 57.4
# 	retrain #4, sparsity 0.03, final_train_loss 1.203e-01, max_acc 66.9, last_acc 66.9, mean_acc 58.0
# 	retrain #5, sparsity 0.04, final_train_loss 1.641e-01, max_acc 63.8, last_acc 63.8, mean_acc 56.3
# 	retrain #6, sparsity 0.05, final_train_loss 3.568e-01, max_acc 65.1, last_acc 65.1, mean_acc 57.3
# 	retrain #7, sparsity 0.06, final_train_loss 2.724e-01, max_acc 67.2, last_acc 64.1, mean_acc 58.3
# 	retrain #8, sparsity 0.07, final_train_loss 2.532e-01, max_acc 65.8, last_acc 63.4, mean_acc 57.6
# 	retrain #9, sparsity 0.08, final_train_loss 1.070e-01, max_acc 66.4, last_acc 66.4, mean_acc 57.0
# 	retrain #10, sparsity 0.09, final_train_loss 7.012e-02, max_acc 65.5, last_acc 62.6, mean_acc 58.0
# 	retrain #11, sparsity 0.10, final_train_loss 5.279e-02, max_acc 67.4, last_acc 65.3, mean_acc 58.8
# 	retrain #12, sparsity 0.11, final_train_loss 1.535e-01, max_acc 66.1, last_acc 66.1, mean_acc 57.2
# 	retrain #13, sparsity 0.12, final_train_loss 8.869e-02, max_acc 65.1, last_acc 62.8, mean_acc 57.7
# 	retrain #14, sparsity 0.13, final_train_loss 1.644e-01, max_acc 65.1, last_acc 64.3, mean_acc 58.1
# 	retrain #15, sparsity 0.14, final_train_loss 9.897e-02, max_acc 67.2, last_acc 65.0, mean_acc 59.1
# 	retrain #16, sparsity 0.15, final_train_loss 1.059e-01, max_acc 67.8, last_acc 65.3, mean_acc 58.7
# 	retrain #17, sparsity 0.16, final_train_loss 1.969e-01, max_acc 65.8, last_acc 62.9, mean_acc 58.0
# 	retrain #18, sparsity 0.17, final_train_loss 1.477e-01, max_acc 65.4, last_acc 64.5, mean_acc 58.4
# 	retrain #19, sparsity 0.18, final_train_loss 1.015e-01, max_acc 66.8, last_acc 64.1, mean_acc 58.4
# 	retrain #20, sparsity 0.19, final_train_loss 9.848e-02, max_acc 65.7, last_acc 64.2, mean_acc 57.5
# 	retrain #21, sparsity 0.20, final_train_loss 1.973e-01, max_acc 66.0, last_acc 63.0, mean_acc 58.4
# 	retrain #22, sparsity 0.21, final_train_loss 2.288e-01, max_acc 64.0, last_acc 61.8, mean_acc 57.6
# 	retrain #23, sparsity 0.22, final_train_loss 1.990e-01, max_acc 65.7, last_acc 64.7, mean_acc 58.2
# 	retrain #24, sparsity 0.23, final_train_loss 3.170e-01, max_acc 66.3, last_acc 65.1, mean_acc 58.9
# 	retrain #25, sparsity 0.24, final_train_loss 2.287e-01, max_acc 67.6, last_acc 65.9, mean_acc 59.6
# 	retrain #26, sparsity 0.25, final_train_loss 6.162e-02, max_acc 67.0, last_acc 66.0, mean_acc 59.3
# 	retrain #27, sparsity 0.26, final_train_loss 1.275e-01, max_acc 67.3, last_acc 64.1, mean_acc 60.0
# 	retrain #28, sparsity 0.27, final_train_loss 2.391e-01, max_acc 64.9, last_acc 64.2, mean_acc 58.9
# 	retrain #29, sparsity 0.28, final_train_loss 2.677e-01, max_acc 64.9, last_acc 62.9, mean_acc 58.9
# 	retrain #30, sparsity 0.29, final_train_loss 1.782e-01, max_acc 65.8, last_acc 62.4, mean_acc 59.1
# 	retrain #31, sparsity 0.30, final_train_loss 2.360e-01, max_acc 67.6, last_acc 67.6, mean_acc 59.9
# 	retrain #32, sparsity 0.31, final_train_loss 6.158e-02, max_acc 65.2, last_acc 63.9, mean_acc 59.7
# 	retrain #33, sparsity 0.32, final_train_loss 3.731e-01, max_acc 66.0, last_acc 63.3, mean_acc 59.5
# 	retrain #34, sparsity 0.33, final_train_loss 3.098e-01, max_acc 66.9, last_acc 63.7, mean_acc 59.9
# 	retrain #35, sparsity 0.34, final_train_loss 1.147e-01, max_acc 66.5, last_acc 64.6, mean_acc 59.8
# 	retrain #36, sparsity 0.35, final_train_loss 1.722e-01, max_acc 67.9, last_acc 65.4, mean_acc 60.6
# 	retrain #37, sparsity 0.36, final_train_loss 1.644e-01, max_acc 66.7, last_acc 66.0, mean_acc 60.3
# 	retrain #38, sparsity 0.37, final_train_loss 2.120e-01, max_acc 67.7, last_acc 67.7, mean_acc 60.8
# 	retrain #39, sparsity 0.38, final_train_loss 7.557e-02, max_acc 66.4, last_acc 66.1, mean_acc 60.7
# 	retrain #40, sparsity 0.39, final_train_loss 1.247e-01, max_acc 68.3, last_acc 64.2, mean_acc 61.0
# 	retrain #41, sparsity 0.40, final_train_loss 1.773e-01, max_acc 67.4, last_acc 63.9, mean_acc 60.3
# 	retrain #42, sparsity 0.41, final_train_loss 1.006e-01, max_acc 67.1, last_acc 67.1, mean_acc 60.5
# 	retrain #43, sparsity 0.42, final_train_loss 8.634e-02, max_acc 68.5, last_acc 66.5, mean_acc 61.1
# 	retrain #44, sparsity 0.43, final_train_loss 3.696e-02, max_acc 68.1, last_acc 66.1, mean_acc 61.7
# 	retrain #45, sparsity 0.44, final_train_loss 3.335e-01, max_acc 67.8, last_acc 66.5, mean_acc 61.3
# 	retrain #46, sparsity 0.45, final_train_loss 1.774e-01, max_acc 67.6, last_acc 66.8, mean_acc 61.2
# 	retrain #47, sparsity 0.46, final_train_loss 1.277e-01, max_acc 69.1, last_acc 69.1, mean_acc 61.7
# 	retrain #48, sparsity 0.47, final_train_loss 3.559e-01, max_acc 68.8, last_acc 68.4, mean_acc 61.4
# 	retrain #49, sparsity 0.48, final_train_loss 4.849e-02, max_acc 69.0, last_acc 69.0, mean_acc 61.2
# 	retrain #50, sparsity 0.49, final_train_loss 1.402e-01, max_acc 68.4, last_acc 68.3, mean_acc 62.7
# 	retrain #51, sparsity 0.51, final_train_loss 2.873e-02, max_acc 69.9, last_acc 65.7, mean_acc 62.7
# 	retrain #52, sparsity 0.52, final_train_loss 2.881e-01, max_acc 68.5, last_acc 68.5, mean_acc 62.2
# 	retrain #53, sparsity 0.53, final_train_loss 4.186e-02, max_acc 68.2, last_acc 66.7, mean_acc 61.5
# 	retrain #54, sparsity 0.54, final_train_loss 4.502e-02, max_acc 67.7, last_acc 67.6, mean_acc 61.9
# 	retrain #55, sparsity 0.55, final_train_loss 1.147e-01, max_acc 70.5, last_acc 69.1, mean_acc 62.9
# 	retrain #56, sparsity 0.56, final_train_loss 1.826e-01, max_acc 69.0, last_acc 65.7, mean_acc 62.5
# 	retrain #57, sparsity 0.57, final_train_loss 2.663e-01, max_acc 68.7, last_acc 65.3, mean_acc 61.9
# 	retrain #58, sparsity 0.58, final_train_loss 2.607e-02, max_acc 68.7, last_acc 68.7, mean_acc 61.8
# 	retrain #59, sparsity 0.59, final_train_loss 2.473e-02, max_acc 70.2, last_acc 69.1, mean_acc 63.6
# 	retrain #60, sparsity 0.60, final_train_loss 9.797e-02, max_acc 69.5, last_acc 68.0, mean_acc 63.3
# 	retrain #61, sparsity 0.61, final_train_loss 6.205e-02, max_acc 70.6, last_acc 70.6, mean_acc 63.2
# 	retrain #62, sparsity 0.62, final_train_loss 3.348e-01, max_acc 69.3, last_acc 67.2, mean_acc 63.1
# 	retrain #63, sparsity 0.63, final_train_loss 9.532e-02, max_acc 70.9, last_acc 69.4, mean_acc 63.7
# 	retrain #64, sparsity 0.64, final_train_loss 3.584e-01, max_acc 72.3, last_acc 65.8, mean_acc 63.5
# 	retrain #65, sparsity 0.65, final_train_loss 1.759e-01, max_acc 69.3, last_acc 64.9, mean_acc 62.5
# 	retrain #66, sparsity 0.66, final_train_loss 6.222e-02, max_acc 70.2, last_acc 68.4, mean_acc 63.5
# 	retrain #67, sparsity 0.67, final_train_loss 2.219e-01, max_acc 71.3, last_acc 68.6, mean_acc 63.9
# 	retrain #68, sparsity 0.68, final_train_loss 5.663e-02, max_acc 69.2, last_acc 67.5, mean_acc 63.1
# 	retrain #69, sparsity 0.69, final_train_loss 8.171e-02, max_acc 72.4, last_acc 71.7, mean_acc 64.8
# 	retrain #70, sparsity 0.70, final_train_loss 1.601e-01, max_acc 70.5, last_acc 70.5, mean_acc 63.8
# 	retrain #71, sparsity 0.71, final_train_loss 1.390e-02, max_acc 71.9, last_acc 71.9, mean_acc 64.5
# 	retrain #72, sparsity 0.72, final_train_loss 9.511e-02, max_acc 72.3, last_acc 70.8, mean_acc 65.3
# 	retrain #73, sparsity 0.73, final_train_loss 1.681e-01, max_acc 71.8, last_acc 70.8, mean_acc 65.3
# 	retrain #74, sparsity 0.74, final_train_loss 1.407e-01, max_acc 71.9, last_acc 71.4, mean_acc 65.6
# 	retrain #75, sparsity 0.75, final_train_loss 5.924e-02, max_acc 74.5, last_acc 71.7, mean_acc 65.8
# 	retrain #76, sparsity 0.76, final_train_loss 4.582e-02, max_acc 70.5, last_acc 70.0, mean_acc 64.7
# 	retrain #77, sparsity 0.77, final_train_loss 6.800e-04, max_acc 74.9, last_acc 73.6, mean_acc 66.6
# 	retrain #78, sparsity 0.78, final_train_loss 1.203e-01, max_acc 72.1, last_acc 70.7, mean_acc 65.5
# 	retrain #79, sparsity 0.79, final_train_loss 9.717e-03, max_acc 74.1, last_acc 74.1, mean_acc 65.9
# 	retrain #80, sparsity 0.80, final_train_loss 2.033e-02, max_acc 72.2, last_acc 70.7, mean_acc 65.2
# 	retrain #81, sparsity 0.81, final_train_loss 5.311e-02, max_acc 72.3, last_acc 68.6, mean_acc 66.1
# 	retrain #82, sparsity 0.82, final_train_loss 5.294e-03, max_acc 74.2, last_acc 73.1, mean_acc 66.3
# 	retrain #83, sparsity 0.83, final_train_loss 1.592e-01, max_acc 73.7, last_acc 69.4, mean_acc 66.1
# 	retrain #84, sparsity 0.84, final_train_loss 9.547e-03, max_acc 73.6, last_acc 73.6, mean_acc 66.1
# 	retrain #85, sparsity 0.85, final_train_loss 4.443e-02, max_acc 73.2, last_acc 70.9, mean_acc 66.4
# 	retrain #86, sparsity 0.86, final_train_loss 4.789e-02, max_acc 72.8, last_acc 72.8, mean_acc 66.2
# 	retrain #87, sparsity 0.87, final_train_loss 3.173e-03, max_acc 74.8, last_acc 74.8, mean_acc 67.9
# 	retrain #88, sparsity 0.88, final_train_loss 1.996e-01, max_acc 73.5, last_acc 71.1, mean_acc 67.2
# 	retrain #89, sparsity 0.89, final_train_loss 1.135e-01, max_acc 74.0, last_acc 71.9, mean_acc 66.4
# 	retrain #90, sparsity 0.90, final_train_loss 7.585e-02, max_acc 73.9, last_acc 71.4, mean_acc 67.3
# 	retrain #91, sparsity 0.91, final_train_loss 4.163e-03, max_acc 74.5, last_acc 73.9, mean_acc 67.5
# 	retrain #92, sparsity 0.92, final_train_loss 2.933e-02, max_acc 74.4, last_acc 74.4, mean_acc 68.4
# 	retrain #93, sparsity 0.93, final_train_loss 1.358e-02, max_acc 74.0, last_acc 72.1, mean_acc 66.9
# 	retrain #94, sparsity 0.94, final_train_loss 3.754e-02, max_acc 73.7, last_acc 71.8, mean_acc 66.3
# 	retrain #95, sparsity 0.95, final_train_loss 6.981e-02, max_acc 73.1, last_acc 73.1, mean_acc 66.3
# 	retrain #96, sparsity 0.96, final_train_loss 1.728e-01, max_acc 69.6, last_acc 69.6, mean_acc 63.5
# 	retrain #97, sparsity 0.97, final_train_loss 2.380e-01, max_acc 68.2, last_acc 67.1, mean_acc 62.1
# 	retrain #98, sparsity 0.98, final_train_loss 5.829e-01, max_acc 61.4, last_acc 60.9, mean_acc 55.3
# 	retrain #99, sparsity 0.99, final_train_loss 8.980e-01, max_acc 51.0, last_acc 50.8, mean_acc 46.2
# 	retrain #100, sparsity 1.00, final_train_loss 2.303e+00, max_acc 10.2, last_acc 10.2, mean_acc 10.2

# %%
test_losses = lott_stats['test_losses'][:,-1]
test_accs = lott_stats['test_accs'][:,-1]

fig,ax = plt.subplots()
ax.plot(sparsity_schedule, test_losses,'r-')
ax.plot((sparsity_schedule[0], sparsity_schedule[-1]),(test_losses[0], test_losses[0]),'k--',label='dense')
ax.set_xlabel('Sparsity')
ax.set_ylabel('Loss')
ax.set_xlim(0,1)
ax.legend()
plt.show()

fig,ax = plt.subplots()
ax.plot(sparsity_schedule, 100-test_accs,'r-')
ax.plot((sparsity_schedule[0], sparsity_schedule[-1]),(100-test_accs[0], 100-test_accs[0]),'k--',label='dense')
ax.set_xlabel('Sparsity')
ax.set_ylabel('Percent Error')
ax.set_xlim(0,1)
ax.set_ylim(0,100)
ax.legend()
plt.show()

# %% [markdown]
# You should see that the test loss decreases and the errors decrease with more as the network gets sparser.  The dashed line represents the original dense (unpruned) network.  We have identified a simpler network that was "inside" the original network for which the results are superior.  Of course if we make it too sparse, then it gets worse again.
#
# This phenomenon is explored much further in the original notebook by Sam Greydanus which can be found [here](https://github.com/greydanus/mnist1d).
